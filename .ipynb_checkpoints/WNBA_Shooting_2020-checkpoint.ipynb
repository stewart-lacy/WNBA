# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
file_to_load = pd.read_csv("WNBA_Shooting_.csv")
pd.set_option('display.max_columns', None)
file_to_load['Count'] =1
file_to_load
# Out:
#             PLAYER_NAME        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 0        Natasha Howard              Mid-Range          Right Side(R)
# 1           Kiah Stokes  In The Paint (Non-RA)              Center(C)
# 2       Breanna Stewart        Restricted Area              Center(C)
# 3        Amanda Zahui B              Mid-Range              Center(C)
# 4     Layshia Clarendon        Restricted Area              Center(C)
# ...                 ...                    ...                    ...
# 8030     Brittney Sykes              Mid-Range           Left Side(L)
# 8031       Chelsea Gray        Restricted Area              Center(C)
# 8032     Nneka Ogwumike              Mid-Range  Right Side Center(RC)
# 8033      Kayla McBride      Above the Break 3          Right Side(R)
# 8034  Danielle Robinson        Restricted Area              Center(C)
#
#       SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 0            8-16 ft.             10    107     -9      1
# 1     Less Than 8 ft.              5    -30     41      1
# 2     Less Than 8 ft.              1    -15      0      1
# 3           16-24 ft.             17     -1    176      1
# 4     Less Than 8 ft.              2     21     14      1
# ...               ...            ...    ...    ...    ...
# 8030         8-16 ft.             11   -111     39      1
# 8031  Less Than 8 ft.              0      0     -6      1
# 8032        16-24 ft.             18     72    168      1
# 8033          24+ ft.             22    225     43      1
# 8034  Less Than 8 ft.              2     23     11      1
#
# [8035 rows x 8 columns]

# %% [markdown]
# # Left Corner 3

# %%
L_Corner_3=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Left Corner 3']
L_Corner_3=L_Corner_3.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
L_Corner_3
# Out:
#                   Count
# PLAYER_NAME
# Jewell Loyd           8
# Riquna Williams       6
# Alysha Clark          5
# Azurá Stevens         3
# Brittney Sykes        3
# Allie Quigley         3
# Sue Bird              3
# Bridget Carleton      3
# Ariel Atkins          3
# Marina Mabrey         2

# %%
left_corner_3=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Left Corner 3']
left_corner_3_made=left_corner_3.loc[left_corner_3['PLAYER_NAME'] =='Jewell Loyd']
left_corner_3_made
# Out:
#       PLAYER_NAME SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540   Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 1242  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 2270  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3055  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3057  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3319  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 6702  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 7466  Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# 3319             22   -228    -15      1
# 6702             23   -230     -9      1
# 7466             23   -231    -11      1

# %% [markdown]
# # Right Corner 3

# %%
R_Corner_3=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Right Corner 3']
R_Corner_3.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                   Count
# PLAYER_NAME
# Satou Sabally         3
# Sami Whitcomb         2
# Leilani Mitchell      2
# Kayla Thornton        2
# Tiffany Mitchell      1
# Kahleah Copper        1
# Allisha Gray          1
# Azurá Stevens         1
# Betnijah Laney        1
# Brittney Sykes        1

# %%
right_corner_3=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Right Corner 3']
right_corner_3_made=right_corner_3.loc[right_corner_3['PLAYER_NAME'] =='Satou Sabally']
Shots_made_onCourt=left_corner_3_made.append(right_corner_3_made)
Shots_made_onCourt
# Out:
#         PLAYER_NAME SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540     Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 1242    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 2270    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3055    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3057    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3319    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 6702    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 7466    Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 363   Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7427  Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7429  Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# 3319             22   -228    -15      1
# 6702             23   -230     -9      1
# 7466             23   -231    -11      1
# 363              22    227     14      1
# 7427             23    232     11      1
# 7429             23    232     17      1

# %% [markdown]
# # Mid Range

# %%
Mid_Range=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Mid-Range']
Mid_Range.SHOT_ZONE_AREA.unique()
# Out:
# array(['Right Side(R)', 'Center(C)', 'Left Side(L)',
#        'Left Side Center(LC)', 'Right Side Center(RC)'], dtype=object)

# %% [markdown]
# ### Right Side

# %%
Mid_Range=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Mid-Range']
Mid_Range_Right = Mid_Range.loc[Mid_Range['SHOT_ZONE_AREA'] =='Right Side(R)']
Mid_Range_Right.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                     Count
# PLAYER_NAME
# Courtney Williams      17
# Candice Dupree         16
# Allie Quigley          14
# Nneka Ogwumike          8
# Chelsea Gray            8
# Emma Meesseman          8
# Myisha Hines-Allen      8
# Brittney Griner         7
# Kia Vaughn              7
# Seimone Augustus        7

# %%
mid_range_Right_Side__made=Mid_Range_Right.loc[Mid_Range_Right['PLAYER_NAME'] == 'Courtney Williams']
mid_range_Right_Side__made

Shots_made_onCourt=Shots_made_onCourt.append(mid_range_Right_Side__made)
Shots_made_onCourt
# Out:
#             PLAYER_NAME SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540         Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 1242        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 2270        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3055        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3057        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3319        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 6702        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 7466        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 363       Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7427      Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7429      Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 1387  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 1392  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 2240  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3397  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3613  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 3622  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3643  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 4418  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 4779  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 5505  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 5532  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 6074  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 6076  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 6774  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 7396  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 7688  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 7719  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# 3319             22   -228    -15      1
# 6702             23   -230     -9      1
# 7466             23   -231    -11      1
# 363              22    227     14      1
# 7427             23    232     11      1
# 7429             23    232     17      1
# 1387              9     97     23      1
# 1392             14    135     62      1
# 2240             13    130     35      1
# 3397             14    137     29      1
# 3613             20    193     71      1
# 3622             14     96    102      1
# 3643             13     93     96      1
# 4418             17    178     14      1
# 4779             17    172      7      1
# 5505             17    169     33      1
# 5532             20    194     61      1
# 6074             18    180      9      1
# 6076             13    137     22      1
# 6774             14    147     18      1
# 7396             17    175     36      1
# 7688             16    164     20      1
# 7719             12     83     92      1

# %% [markdown]
# ### Center

# %%
Mid_Range=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Mid-Range']
Mid_Range_Center = Mid_Range.loc[Mid_Range['SHOT_ZONE_AREA'] =='Center(C)']
Mid_Range_Center.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                      Count
# PLAYER_NAME
# Kayla McBride           16
# Allie Quigley           15
# Ariel Atkins            15
# A'ja Wilson             13
# Chelsea Gray            13
# Courtney Williams       12
# Jewell Loyd             10
# Jackie Young            10
# Angel McCoughtry         9
# Crystal Dangerfield      8

# %%
Mid_Range_made=Mid_Range_Center.loc[Mid_Range_Center['PLAYER_NAME'] == 'Kayla McBride']

Shots_made_onCourt=Shots_made_onCourt.append(Mid_Range_made)
Shots_made_onCourt
# Out:
#             PLAYER_NAME SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540         Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 1242        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 2270        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3055        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3057        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3319        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 6702        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 7466        Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 363       Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7427      Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 7429      Satou Sabally  Right Corner 3  Right Side(R)         24+ ft.
# 1387  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 1392  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 2240  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3397  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3613  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 3622  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 3643  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 4418  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 4779  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 5505  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 5532  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 6074  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 6076  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 6774  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 7396  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 7688  Courtney Williams       Mid-Range  Right Side(R)       16-24 ft.
# 7719  Courtney Williams       Mid-Range  Right Side(R)        8-16 ft.
# 1422      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 2413      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 2777      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 2831      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 3197      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 3568      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 4326      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 4357      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 5026      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 5454      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 6144      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 6414      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 6776      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 6792      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 7595      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
# 7999      Kayla McBride       Mid-Range      Center(C)       16-24 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# 3319             22   -228    -15      1
# 6702             23   -230     -9      1
# 7466             23   -231    -11      1
# 363              22    227     14      1
# 7427             23    232     11      1
# 7429             23    232     17      1
# 1387              9     97     23      1
# 1392             14    135     62      1
# 2240             13    130     35      1
# 3397             14    137     29      1
# 3613             20    193     71      1
# 3622             14     96    102      1
# 3643             13     93     96      1
# 4418             17    178     14      1
# 4779             17    172      7      1
# 5505             17    169     33      1
# 5532             20    194     61      1
# 6074             18    180      9      1
# 6076             13    137     22      1
# 6774             14    147     18      1
# 7396             17    175     36      1
# 7688             16    164     20      1
# 7719             12     83     92      1
# 1422             21     58    205      1
# 2413             17     45    166      1
# 2777             19    -14    191      1
# 2831             19     22    195      1
# 3197             21     64    206      1
# 3568             21     23    210      1
# 4326             18      3    188      1
# 4357             18    -49    182      1
# 5026             18     47    181      1
# 5454             19     11    192      1
# 6144             22     -4    224      1
# 6414             16    -24    164      1
# 6776             19     57    190      1
# 6792             20     11    207      1
# 7595             21     29    216      1
# 7999             20     17    203      1

# %% [markdown]
# ### Left Side Center

# %%
Mid_Range_LC = Mid_Range.loc[Mid_Range['SHOT_ZONE_AREA'] =='Left Side Center(LC)']
Mid_Range_LC.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                    Count
# PLAYER_NAME
# Courtney Williams     13
# Jasmine Thomas        11
# Arike Ogunbowale      11
# Kahleah Copper         9
# Riquna Williams        8
# DeWanna Bonner         8
# Jackie Young           7
# Emma Meesseman         7
# Chelsea Gray           7
# Allie Quigley          6

# %%
Mid_Range_LC_made=Mid_Range_LC.loc[Mid_Range_LC['PLAYER_NAME'] == 'Courtney Williams']
Mid_Range_LC_made
Shots_made_onCourt=Shots_made_onCourt.append(Mid_Range_LC_made)
Shots_made_onCourt
# Out:
#             PLAYER_NAME SHOT_ZONE_BASIC        SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540         Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 1242        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 2270        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 3055        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 3057        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 3319        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 6702        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 7466        Jewell Loyd   Left Corner 3          Left Side(L)         24+ ft.
# 363       Satou Sabally  Right Corner 3         Right Side(R)         24+ ft.
# 7427      Satou Sabally  Right Corner 3         Right Side(R)         24+ ft.
# 7429      Satou Sabally  Right Corner 3         Right Side(R)         24+ ft.
# 1387  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 1392  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 2240  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 3397  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 3613  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 3622  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 3643  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 4418  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 4779  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 5505  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 5532  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 6074  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 6076  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 6774  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 7396  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 7688  Courtney Williams       Mid-Range         Right Side(R)       16-24 ft.
# 7719  Courtney Williams       Mid-Range         Right Side(R)        8-16 ft.
# 1422      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 2413      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 2777      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 2831      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 3197      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 3568      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 4326      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 4357      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 5026      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 5454      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 6144      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 6414      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 6776      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 6792      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 7595      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 7999      Kayla McBride       Mid-Range             Center(C)       16-24 ft.
# 1854  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 2214  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 2556  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 3377  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 4013  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 4031  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 5928  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 5935  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 5983  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 6816  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 7382  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 7408  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
# 7740  Courtney Williams       Mid-Range  Left Side Center(LC)       16-24 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# 3319             22   -228    -15      1
# 6702             23   -230     -9      1
# 7466             23   -231    -11      1
# 363              22    227     14      1
# 7427             23    232     11      1
# 7429             23    232     17      1
# 1387              9     97     23      1
# 1392             14    135     62      1
# 2240             13    130     35      1
# 3397             14    137     29      1
# 3613             20    193     71      1
# 3622             14     96    102      1
# 3643             13     93     96      1
# 4418             17    178     14      1
# 4779             17    172      7      1
# 5505             17    169     33      1
# 5532             20    194     61      1
# 6074             18    180      9      1
# 6076             13    137     22      1
# 6774             14    147     18      1
# 7396             17    175     36      1
# 7688             16    164     20      1
# 7719             12     83     92      1
# 1422             21     58    205      1
# 2413             17     45    166      1
# 2777             19    -14    191      1
# 2831             19     22    195      1
# 3197             21     64    206      1
# 3568             21     23    210      1
# 4326             18      3    188      1
# 4357             18    -49    182      1
# 5026             18     47    181      1
# 5454             19     11    192      1
# 6144             22     -4    224      1
# 6414             16    -24    164      1
# 6776             19     57    190      1
# 6792             20     11    207      1
# 7595             21     29    216      1
# 7999             20     17    203      1
# 1854             17    -75    157      1
# 2214             18   -116    139      1
# 2556             20   -140    152      1
# 3377             16   -132     97      1
# 4013             17    -62    160      1
# 4031             19   -147    122      1
# 5928             19    -60    181      1
# 5935             17   -124    119      1
# 5983             20    -96    181      1
# 6816             20    -91    184      1
# 7382             17   -128    120      1
# 7408             18    -70    170      1
# 7740             19    -92    170      1

# %% [markdown]
# ### Right Side Center

# %%
Mid_Range_RC = Mid_Range.loc[Mid_Range['SHOT_ZONE_AREA'] =='Right Side Center(RC)']
Mid_Range_RC.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                       Count
# PLAYER_NAME
# Courtney Williams        24
# Chelsea Gray             11
# Candice Dupree            9
# A'ja Wilson               8
# Courtney Vandersloot      8
# Allie Quigley             7
# Jasmine Thomas            7
# Betnijah Laney            7
# Kayla McBride             6
# Jackie Young              6

# %%
Mid_Range_RC_made=Mid_Range_RC.loc[Mid_Range_RC['PLAYER_NAME'] == 'Courtney Williams']
Mid_Range_RC_made
Shots_made_onCourt=Shots_made_onCourt.append(Mid_Range_RC_made)
Shots_made_onCourt
# Out:
#             PLAYER_NAME SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 540         Jewell Loyd   Left Corner 3           Left Side(L)
# 1242        Jewell Loyd   Left Corner 3           Left Side(L)
# 2270        Jewell Loyd   Left Corner 3           Left Side(L)
# 3055        Jewell Loyd   Left Corner 3           Left Side(L)
# 3057        Jewell Loyd   Left Corner 3           Left Side(L)
# ...                 ...             ...                    ...
# 7376  Courtney Williams       Mid-Range  Right Side Center(RC)
# 7394  Courtney Williams       Mid-Range  Right Side Center(RC)
# 7416  Courtney Williams       Mid-Range  Right Side Center(RC)
# 7720  Courtney Williams       Mid-Range  Right Side Center(RC)
# 7727  Courtney Williams       Mid-Range  Right Side Center(RC)
#
#      SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540          24+ ft.             23   -237     -7      1
# 1242         24+ ft.             23   -237    -12      1
# 2270         24+ ft.             22   -226     -7      1
# 3055         24+ ft.             22   -226     12      1
# 3057         24+ ft.             23   -232      1      1
# ...              ...            ...    ...    ...    ...
# 7376       16-24 ft.             17    124    120      1
# 7394       16-24 ft.             17     74    163      1
# 7416       16-24 ft.             17    100    149      1
# 7720       16-24 ft.             17    122    127      1
# 7727       16-24 ft.             20    150    133      1
#
# [81 rows x 8 columns]

# %% [markdown]
# ### Left Side

# %%
Mid_Range_LS=Mid_Range.loc[Mid_Range['SHOT_ZONE_AREA'] == 'Left Side(L)']
Mid_Range_LS.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                    Count
# PLAYER_NAME
# Candice Dupree        16
# Courtney Williams     13
# Seimone Augustus      11
# Chennedy Carter       11
# A'ja Wilson           11
# Ariel Atkins          11
# Betnijah Laney        10
# Napheesa Collier      10
# DeWanna Bonner        10
# Emma Meesseman        10

# %%
Mid_Range_LS_made = Mid_Range_LS.loc[Mid_Range_LS['PLAYER_NAME'] == 'Candice Dupree']
Mid_Range_LS_made
Shots_made_onCourt=Shots_made_onCourt.append(Mid_Range_LS_made)
Shots_made_onCourt
# Out:
#          PLAYER_NAME SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540      Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 1242     Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 2270     Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3055     Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# 3057     Jewell Loyd   Left Corner 3   Left Side(L)         24+ ft.
# ...              ...             ...            ...             ...
# 5698  Candice Dupree       Mid-Range   Left Side(L)       16-24 ft.
# 6473  Candice Dupree       Mid-Range   Left Side(L)        8-16 ft.
# 6751  Candice Dupree       Mid-Range   Left Side(L)        8-16 ft.
# 7258  Candice Dupree       Mid-Range   Left Side(L)       16-24 ft.
# 7949  Candice Dupree       Mid-Range   Left Side(L)        8-16 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# ...             ...    ...    ...    ...
# 5698             16   -165     26      1
# 6473             12    -93     78      1
# 6751             13   -130     36      1
# 7258             16   -163     31      1
# 7949             12   -125     18      1
#
# [97 rows x 8 columns]

# %% [markdown]
# # In the paint (NON_RA)

# %%
In_the_paint_nra=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] =='In The Paint (Non-RA)']
In_the_paint_nra.SHOT_ZONE_AREA.unique()
# Out:
# array(['Center(C)', 'Left Side(L)', 'Right Side(R)'], dtype=object)

# %% [markdown]
# ### Center

# %%
NRA_Center=In_the_paint_nra.loc[In_the_paint_nra['SHOT_ZONE_AREA'] == 'Center(C)']
NRA_Center.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                       Count
# PLAYER_NAME
# Alyssa Thomas            56
# A'ja Wilson              50
# Myisha Hines-Allen       48
# Brittney Griner          40
# Arike Ogunbowale         39
# Napheesa Collier         38
# Skylar Diggins-Smith     35
# Angel McCoughtry         34
# DeWanna Bonner           33
# Emma Meesseman           33

# %%
NRA_Center_made=NRA_Center.loc[NRA_Center['PLAYER_NAME'] == 'Alyssa Thomas']
NRA_Center_made
Shots_made_onCourt=Shots_made_onCourt.append(NRA_Center_made)
Shots_made_onCourt
# Out:
#         PLAYER_NAME        SHOT_ZONE_BASIC SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 540     Jewell Loyd          Left Corner 3   Left Side(L)          24+ ft.
# 1242    Jewell Loyd          Left Corner 3   Left Side(L)          24+ ft.
# 2270    Jewell Loyd          Left Corner 3   Left Side(L)          24+ ft.
# 3055    Jewell Loyd          Left Corner 3   Left Side(L)          24+ ft.
# 3057    Jewell Loyd          Left Corner 3   Left Side(L)          24+ ft.
# ...             ...                    ...            ...              ...
# 7314  Alyssa Thomas  In The Paint (Non-RA)      Center(C)  Less Than 8 ft.
# 7329  Alyssa Thomas  In The Paint (Non-RA)      Center(C)  Less Than 8 ft.
# 7334  Alyssa Thomas  In The Paint (Non-RA)      Center(C)         8-16 ft.
# 7686  Alyssa Thomas  In The Paint (Non-RA)      Center(C)  Less Than 8 ft.
# 7692  Alyssa Thomas  In The Paint (Non-RA)      Center(C)  Less Than 8 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# ...             ...    ...    ...    ...
# 7314              4      2     45      1
# 7329              4     36     20      1
# 7334              8      0     83      1
# 7686              4     35     34      1
# 7692              4    -37     24      1
#
# [153 rows x 8 columns]

# %% [markdown]
# ## Restricted Area

# %%
RA=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Restricted Area']
RA.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                     Count
# PLAYER_NAME
# Dearica Hamby          67
# Brionna Jones          67
# Candace Parker         64
# A'ja Wilson            64
# Elizabeth Williams     61
# Napheesa Collier       60
# Kahleah Copper         57
# Alyssa Thomas          56
# DeWanna Bonner         55
# Nneka Ogwumike         54

# %%
RA_made=RA.loc[RA['PLAYER_NAME']=='Dearica Hamby']
RA_made_2=RA.loc[RA["PLAYER_NAME"] =='Brionna Jones' ]
Shots_made_onCourt=Shots_made_onCourt.append(RA_made)
Shots_made_onCourt=Shots_made_onCourt.append(RA_made_2)

Shots_made_onCourt
# Out:
#         PLAYER_NAME  SHOT_ZONE_BASIC SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 540     Jewell Loyd    Left Corner 3   Left Side(L)          24+ ft.
# 1242    Jewell Loyd    Left Corner 3   Left Side(L)          24+ ft.
# 2270    Jewell Loyd    Left Corner 3   Left Side(L)          24+ ft.
# 3055    Jewell Loyd    Left Corner 3   Left Side(L)          24+ ft.
# 3057    Jewell Loyd    Left Corner 3   Left Side(L)          24+ ft.
# ...             ...              ...            ...              ...
# 7335  Brionna Jones  Restricted Area      Center(C)  Less Than 8 ft.
# 7348  Brionna Jones  Restricted Area      Center(C)  Less Than 8 ft.
# 7706  Brionna Jones  Restricted Area      Center(C)  Less Than 8 ft.
# 7714  Brionna Jones  Restricted Area      Center(C)  Less Than 8 ft.
# 7718  Brionna Jones  Restricted Area      Center(C)  Less Than 8 ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# ...             ...    ...    ...    ...
# 7335              3     24     29      1
# 7348              0      0     -6      1
# 7706              2     28      6      1
# 7714              2     24     -1      1
# 7718              1     13     15      1
#
# [287 rows x 8 columns]

# %% [markdown]
# ## Above the Break 3

# %%
Above_The_Break_3=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC'] == 'Above the Break 3']
Above_The_Break_3.SHOT_ZONE_AREA.unique()
# Out:
# array(['Left Side Center(LC)', 'Right Side Center(RC)', 'Left Side(L)',
#        'Center(C)', 'Right Side(R)'], dtype=object)

# %% [markdown]
# ### Left Side Center

# %%
Above_The_Break_3_LC=Above_The_Break_3.loc[Above_The_Break_3['SHOT_ZONE_AREA']=='Left Side Center(LC)']
Above_The_Break_3_LC.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                      Count
# PLAYER_NAME
# Arike Ogunbowale        28
# Diana Taurasi           26
# Allie Quigley           18
# Shekinna Stricklen      18
# Kia Nurse               15
# Ariel Atkins            15
# Crystal Dangerfield     14
# Damiris Dantas          14
# Kelsey Mitchell         13
# Breanna Stewart         13

# %%
Above_The_Break_3_LC_made=Above_The_Break_3_LC.loc[Above_The_Break_3_LC['PLAYER_NAME'] == 'Arike Ogunbowale']
Above_The_Break_3_LC_made

Shots_made_onCourt=Shots_made_onCourt.append(Above_The_Break_3_LC_made)
Shots_made_onCourt
# Out:
#            PLAYER_NAME    SHOT_ZONE_BASIC        SHOT_ZONE_AREA  \
# 540        Jewell Loyd      Left Corner 3          Left Side(L)
# 1242       Jewell Loyd      Left Corner 3          Left Side(L)
# 2270       Jewell Loyd      Left Corner 3          Left Side(L)
# 3055       Jewell Loyd      Left Corner 3          Left Side(L)
# 3057       Jewell Loyd      Left Corner 3          Left Side(L)
# ...                ...                ...                   ...
# 5661  Arike Ogunbowale  Above the Break 3  Left Side Center(LC)
# 5686  Arike Ogunbowale  Above the Break 3  Left Side Center(LC)
# 6952  Arike Ogunbowale  Above the Break 3  Left Side Center(LC)
# 7789  Arike Ogunbowale  Above the Break 3  Left Side Center(LC)
# 7798  Arike Ogunbowale  Above the Break 3  Left Side Center(LC)
#
#      SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540          24+ ft.             23   -237     -7      1
# 1242         24+ ft.             23   -237    -12      1
# 2270         24+ ft.             22   -226     -7      1
# 3055         24+ ft.             22   -226     12      1
# 3057         24+ ft.             23   -232      1      1
# ...              ...            ...    ...    ...    ...
# 5661         24+ ft.             24   -139    201      1
# 5686         24+ ft.             26    -89    250      1
# 6952         24+ ft.             26   -108    238      1
# 7789         24+ ft.             25    -97    234      1
# 7798         24+ ft.             24   -220    101      1
#
# [315 rows x 8 columns]

# %% [markdown]
# ### Right Side Center

# %%
Above_The_Break_3_RC=Above_The_Break_3.loc[Above_The_Break_3['SHOT_ZONE_AREA']=='Right Side Center(RC)']
Above_The_Break_3_RC.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                       Count
# PLAYER_NAME
# Julie Allemand           21
# Kelsey Mitchell          21
# Skylar Diggins-Smith     20
# Damiris Dantas           15
# Marina Mabrey            14
# Diana Taurasi            13
# Allie Quigley            12
# Riquna Williams          12
# Crystal Dangerfield      11
# Sami Whitcomb            11

# %%
Above_The_Break_3_RC_made_1=Above_The_Break_3_RC.loc[Above_The_Break_3_RC['PLAYER_NAME'] =='Kelsey Mitchell']
Above_The_Break_3_RC_made_2 =Above_The_Break_3_RC.loc[Above_The_Break_3_RC['PLAYER_NAME'] =='Julie Allemand']

Shots_made_onCourt=Shots_made_onCourt.append(Above_The_Break_3_RC_made_1)
Shots_made_onCourt=Shots_made_onCourt.append(Above_The_Break_3_RC_made_2)
Shots_made_onCourt
# Out:
#          PLAYER_NAME    SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 540      Jewell Loyd      Left Corner 3           Left Side(L)
# 1242     Jewell Loyd      Left Corner 3           Left Side(L)
# 2270     Jewell Loyd      Left Corner 3           Left Side(L)
# 3055     Jewell Loyd      Left Corner 3           Left Side(L)
# 3057     Jewell Loyd      Left Corner 3           Left Side(L)
# ...              ...                ...                    ...
# 6731  Julie Allemand  Above the Break 3  Right Side Center(RC)
# 7252  Julie Allemand  Above the Break 3  Right Side Center(RC)
# 7260  Julie Allemand  Above the Break 3  Right Side Center(RC)
# 7514  Julie Allemand  Above the Break 3  Right Side Center(RC)
# 7941  Julie Allemand  Above the Break 3  Right Side Center(RC)
#
#      SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540          24+ ft.             23   -237     -7      1
# 1242         24+ ft.             23   -237    -12      1
# 2270         24+ ft.             22   -226     -7      1
# 3055         24+ ft.             22   -226     12      1
# 3057         24+ ft.             23   -232      1      1
# ...              ...            ...    ...    ...    ...
# 6731         24+ ft.             24    164    179      1
# 7252         24+ ft.             25    144    215      1
# 7260         24+ ft.             30    141    270      1
# 7514         24+ ft.             26    129    227      1
# 7941         24+ ft.             24    128    208      1
#
# [357 rows x 8 columns]

# %% [markdown]
# ### Center

# %%
Above_The_Break_3_center=Above_The_Break_3.loc[Above_The_Break_3['SHOT_ZONE_AREA']=='Center(C)']
Above_The_Break_3_center.groupby(by='PLAYER_NAME').sum()['Count'].sort_values(ascending=False).to_frame().head(10)
# Out:
#                       Count
# PLAYER_NAME
# Kelsey Mitchell          18
# Diana Taurasi            17
# Myisha Hines-Allen       14
# Amanda Zahui B           13
# Breanna Stewart          13
# Courtney Vandersloot     11
# Ariel Atkins              9
# DeWanna Bonner            9
# Julie Allemand            8
# Allie Quigley             8

# %%
Above_The_Break_3_center_made=Above_The_Break_3_center.loc[Above_The_Break_3_center["PLAYER_NAME"] =='Kelsey Mitchell']
Above_The_Break_3_center_made

Shots_made_onCourt=Shots_made_onCourt.append(Above_The_Break_3_center_made)
Shots_made_onCourt
# Out:
#           PLAYER_NAME    SHOT_ZONE_BASIC SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 540       Jewell Loyd      Left Corner 3   Left Side(L)         24+ ft.
# 1242      Jewell Loyd      Left Corner 3   Left Side(L)         24+ ft.
# 2270      Jewell Loyd      Left Corner 3   Left Side(L)         24+ ft.
# 3055      Jewell Loyd      Left Corner 3   Left Side(L)         24+ ft.
# 3057      Jewell Loyd      Left Corner 3   Left Side(L)         24+ ft.
# ...               ...                ...            ...             ...
# 5707  Kelsey Mitchell  Above the Break 3      Center(C)       16-24 ft.
# 6488  Kelsey Mitchell  Above the Break 3      Center(C)         24+ ft.
# 6733  Kelsey Mitchell  Above the Break 3      Center(C)       16-24 ft.
# 7235  Kelsey Mitchell  Above the Break 3      Center(C)         24+ ft.
# 7551  Kelsey Mitchell  Above the Break 3      Center(C)         24+ ft.
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 540              23   -237     -7      1
# 1242             23   -237    -12      1
# 2270             22   -226     -7      1
# 3055             22   -226     12      1
# 3057             23   -232      1      1
# ...             ...    ...    ...    ...
# 5707             23    -46    228      1
# 6488             25    -52    253      1
# 6733             23    -22    233      1
# 7235             24    -28    244      1
# 7551             25     36    253      1
#
# [375 rows x 8 columns]

# %%
backcourt=file_to_load.loc[file_to_load['SHOT_ZONE_BASIC']=='Backcourt']
backcourt
# Out:
#         PLAYER_NAME SHOT_ZONE_BASIC  SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 6025  Jazmine Jones       Backcourt  Back Court(BC)  Back Court Shot
#
#       SHOT_DISTANCE  LOC_X  LOC_Y  Count
# 6025             48    207    439      1

# %%
L_Corner_3_df = ['Jewell Loyd', 'Left Corner 3','Left Side(L)']
R_Corner_3df = ['Satou Sabally', 'Right Corner 3','Right Side(R)']
Mid_Range_Right_df = ['Courtney Williams', 'Mid-Range', 'Right Side(R)']
Mid_Range_Center_df = ['Kayla McBride','Mid-Range','Center']
Mid_Range_Left_Side_Center_df= ['Courtney Williams','Mid-Range','Left Side Center']
Mid_Range_Right_Side_Center_df = ['Courtney Williams','Mid-Range', 'Right Side Center']
Mid_Range_Left_df = ['Candice Dupree','Mid-Range','Left Side (L)']
NRA_Center_df = ['Alyssa Thomas', 'In The Paint (Non-RA)','Center']
Restricted_Area_df = ['Dearica Hamby and Brionna Jones', 'Restricted Area', 'Center']
Above_The_Break_3_LC_df = ['Arike Ogunbowale', 'Above The Break 3', 'Left Side Center (LC)']
Above_The_Break_3_RC_df = ['Julie Allemand and Kelsey Mitchell', 'Above The Break 3', 'RIght Side Center (RC)']
Above_The_Break_3_center_df = ['Kelsey Mitchell', 'Above The Break 3', 'Center (C)']
Top_WNBA_Shooting_for2020=pd.DataFrame(columns = ['Player Name', 'Shot Zone Basic','Shot Zone Area'])

# %%
frames = [L_Corner_3_df, R_Corner_3df, Mid_Range_Right_df, Mid_Range_Center_df, Mid_Range_Left_Side_Center_df, Mid_Range_Right_Side_Center_df, Mid_Range_Left_df, NRA_Center_df, Restricted_Area_df,Above_The_Break_3_LC_df,Above_The_Break_3_RC_df,Above_The_Break_3_center_df]

Top_WNBA_Shooting_for2020=pd.DataFrame(frames, columns = ['Player Name', 'Shot Zone Basic','Shot Zone Area'])
Top_WNBA_Shooting_for2020
# Out:
#                            Player Name        Shot Zone Basic  \
# 0                          Jewell Loyd          Left Corner 3
# 1                        Satou Sabally         Right Corner 3
# 2                    Courtney Williams              Mid-Range
# 3                        Kayla McBride              Mid-Range
# 4                    Courtney Williams              Mid-Range
# 5                    Courtney Williams              Mid-Range
# 6                       Candice Dupree              Mid-Range
# 7                        Alyssa Thomas  In The Paint (Non-RA)
# 8      Dearica Hamby and Brionna Jones        Restricted Area
# 9                     Arike Ogunbowale      Above The Break 3
# 10  Julie Allemand and Kelsey Mitchell      Above The Break 3
# 11                     Kelsey Mitchell      Above The Break 3
#
#             Shot Zone Area
# 0             Left Side(L)
# 1            Right Side(R)
# 2            Right Side(R)
# 3                   Center
# 4         Left Side Center
# 5        Right Side Center
# 6            Left Side (L)
# 7                   Center
# 8                   Center
# 9    Left Side Center (LC)
# 10  RIght Side Center (RC)
# 11              Center (C)

# %%
import pandas as pd
from scipy.stats import binned_statistic_2d
import seaborn as sns
from bokeh.plotting import figure
from math import pi
# %matplotlib inline

import urllib
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle, Arc
def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((0, 0), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-30, -7.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
plt.figure(figsize=(12,11))
draw_court(outer_lines=True, color="black")
plt.scatter(left_corner_3_made.LOC_X, left_corner_3_made.LOC_Y,label='Jewel Llyod', color='Green')
plt.scatter(right_corner_3_made.LOC_X, right_corner_3_made.LOC_Y,label='Satou Sabally', color="red")
plt.scatter(mid_range_Right_Side__made.LOC_X, mid_range_Right_Side__made.LOC_Y,label='Courtney Wiliams', color="blue")
plt.scatter(Mid_Range_made.LOC_X, Mid_Range_made.LOC_Y,label='Kayla McBride', color="grey")
plt.scatter(Mid_Range_LC_made.LOC_X, Mid_Range_LC_made.LOC_Y,label='Courtney Williams', color="blue")
plt.scatter(Mid_Range_RC_made.LOC_X, Mid_Range_RC_made.LOC_Y,label='Courtney Williams', color="blue")
plt.scatter(Mid_Range_LS_made.LOC_X, Mid_Range_LS_made.LOC_Y,label='Candice Dupree', color="lime")
plt.scatter(NRA_Center_made.LOC_X, NRA_Center_made.LOC_Y,label='Alyssa Thomas', color="pink")
plt.scatter(RA_made.LOC_X, RA_made.LOC_Y,label='Dearica Hamby', color="purple")
plt.scatter(RA_made_2.LOC_X, RA_made_2.LOC_Y,label='Brionna Jones', color="brown")
plt.scatter(Above_The_Break_3_LC_made.LOC_X, Above_The_Break_3_LC_made.LOC_Y,label='Arike Ogunbowale', color="yellow")
plt.scatter(Above_The_Break_3_RC_made_1.LOC_X, Above_The_Break_3_RC_made_1.LOC_Y,label='Kelsey Mitchell', color="gold")
plt.scatter(Above_The_Break_3_RC_made_2.LOC_X, Above_The_Break_3_RC_made_2.LOC_Y,label='Julie Allemand', color="crimson")
plt.scatter(Above_The_Break_3_center_made.LOC_X, Above_The_Break_3_center_made.LOC_Y,label='Kelsey Mitchell', color="gold")
plt.xlim(-300,300)
plt.ylim(-100,500)
plt.legend(loc='upper right')
plt.show()

# %%
import plotly.graph_objects as go
def draw_plotly_court(fig, fig_width=600, margins=10):

    import numpy as np

    # From: https://community.plot.ly/t/arc-shape-with-path/7205/5
    def ellipse_arc(x_center=0.0, y_center=0.0, a=10.5, b=10.5, start_angle=0.0, end_angle=2 * np.pi, N=200, closed=False):
        t = np.linspace(start_angle, end_angle, N)
        x = x_center + a * np.cos(t)
        y = y_center + b * np.sin(t)
        path = f'M {x[0]}, {y[0]}'
        for k in range(1, len(t)):
            path += f'L{x[k]}, {y[k]}'
        if closed:
            path += ' Z'
        return path

    fig_height = fig_width * (470 + 2 * margins) / (500 + 2 * margins)
    fig.update_layout(width=fig_width, height=fig_height)

    # Set axes ranges
    fig.update_xaxes(range=[-250 - margins, 250 + margins])
    fig.update_yaxes(range=[-52.5 - margins, 417.5 + margins])

    threept_break_y = 89.47765084
    three_line_col = "#fa4d00"
    main_line_col = "#fa4d00"

    fig.update_layout(
        # Line Horizontal
        margin=dict(l=20, r=20, t=20, b=20),
        paper_bgcolor='rgb(102,102,102)',
        plot_bgcolor='rgb(102,102,102)',
        yaxis=dict(
            scaleanchor="x",
            scaleratio=1,
            showgrid=False,
            zeroline=False,
            showline=False,
            ticks='',
            showticklabels=False,
            fixedrange=True,
        ),
        xaxis=dict(
            showgrid=False,
            zeroline=False,
            showline=False,
            ticks='',
            showticklabels=False,
            fixedrange=True,
        ),
        shapes=[
            dict(
                type="rect", x0=-250, y0=-52.5, x1=250, y1=417.5,
                line=dict(color=main_line_col, width=1),
                # fillcolor='#333333',
                layer='below'
            ),
            dict(
                type="rect", x0=-80, y0=-52.5, x1=80, y1=137.5,
                line=dict(color=main_line_col, width=1),
                # fillcolor='#333333',
                layer='below'
            ),
            dict(
                type="rect", x0=-60, y0=-52.5, x1=60, y1=137.5,
                line=dict(color=main_line_col, width=1),
                # fillcolor='#333333',
                layer='below'
            ),
            dict(
                type="circle", x0=-60, y0=77.5, x1=60, y1=197.5, xref="x", yref="y",
                line=dict(color=main_line_col, width=1),
                # fillcolor='#dddddd',
                layer='below'
            ),
            dict(
                type="line", x0=-60, y0=137.5, x1=60, y1=137.5,
                line=dict(color=main_line_col, width=1),
                layer='below'
            ),

            dict(
                type="rect", x0=-2, y0=-7.25, x1=2, y1=-12.5,
                line=dict(color="#ec7607", width=1),
                fillcolor='#ec7607',
            ),
            dict(
                type="circle", x0=-7.5, y0=-7.5, x1=7.5, y1=7.5, xref="x", yref="y",
                line=dict(color="#ec7607", width=1),
            ),
            dict(
                type="line", x0=-30, y0=-12.5, x1=30, y1=-12.5,
                line=dict(color="#ec7607", width=1),
            ),

            dict(type="path",
                 path=ellipse_arc(a=40, b=40, start_angle=0, end_angle=np.pi),
                 line=dict(color=main_line_col, width=1), layer='below'),
            dict(type="path",
                 path=ellipse_arc(a=237.5, b=237.5, start_angle=0.386283101, end_angle=np.pi - 0.386283101),
                 line=dict(color=main_line_col, width=1), layer='below'),
            dict(
                type="line", x0=-220, y0=-52.5, x1=-220, y1=threept_break_y,
                line=dict(color=three_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=-220, y0=-52.5, x1=-220, y1=threept_break_y,
                line=dict(color=three_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=220, y0=-52.5, x1=220, y1=threept_break_y,
                line=dict(color=three_line_col, width=1), layer='below'
            ),

            dict(
                type="line", x0=-250, y0=227.5, x1=-220, y1=227.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=250, y0=227.5, x1=220, y1=227.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=-90, y0=17.5, x1=-80, y1=17.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=-90, y0=27.5, x1=-80, y1=27.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=-90, y0=57.5, x1=-80, y1=57.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=-90, y0=87.5, x1=-80, y1=87.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=90, y0=17.5, x1=80, y1=17.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=90, y0=27.5, x1=80, y1=27.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=90, y0=57.5, x1=80, y1=57.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(
                type="line", x0=90, y0=87.5, x1=80, y1=87.5,
                line=dict(color=main_line_col, width=1), layer='below'
            ),
            dict(type="path",
                 path=ellipse_arc(y_center=417.5, a=60, b=60, start_angle=-0, end_angle=-np.pi),
                 line=dict(color=main_line_col, width=1), layer='below'),
        
            dict(
                type= 'line',
                yref= 'y', y0=170, y1= 250,
                xref= 'x', x0=140, x1= 200, 
                line=(dict(color=main_line_col, width=1))
            ),
             dict(
                type= 'line',
                yref= 'y', y0=170, y1= 250,
                xref= 'x', x0=140, x1= 200, 
                line=(dict(color=main_line_col, width=1))
            ),

        ]
    )
    return True

# %%
# import plotly.express as px
x_location=Shots_made_onCourt_df.LOC_X
y_location=Shots_made_onCourt_df.LOC_Y
##Change to left 
left_corner_three = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/204319.png'
Mid_range_left = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/200676.png'
left_three = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1629481.png'
mid_range_center_left = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1627675.png'
top_of_three = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1628909.png'
Mid_range_center = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/203825.png'
in_the_paint = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/203826.png'
ra_1 = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/204324.png'
ra_2 = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1628280.png'
right_corner_3_1 = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1627700.png'
right_corner_3_2 = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1628909.png'
mid_range_center_right = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1627675.png'
mid_range_right = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1627675.png'
right_corner_three = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/wnba/1630149.png'
import plotly.graph_objects as go
import plotly.io as pio
from PIL import Image
# to render in jupyterlab
pio.renderers.default = "plotly_mimetype"


fig = go.Figure()

wnba_logo = Image.open('2321__wnba-primary-2020.png')
draw_plotly_court(fig)
fig.add_layout_image(
    go.layout.Image(
        source=left_corner_three,
        xref="x", yref="y", x=-270, y=30, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=Mid_range_left,
        xref="x", yref="y", x=-175, y=80, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=left_three,
        xref="x", yref="y", x=-250, y=250, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=mid_range_center_left,
        xref="x", yref="y", x=-150, y=200, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
       source=top_of_three,
        xref="x", yref="y", x=-40, y=315, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))

fig.add_layout_image(   
    go.layout.Image(
        source=Mid_range_center,
        xref="x", yref="y", x=-40, y=225, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=in_the_paint,
        xref="x", yref="y", x=-40, y=135, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=ra_1,
        xref="x", yref="y", x=-75, y=50, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=ra_2,
        xref="x", yref="y", x=0, y=50, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=right_corner_3_1,
        xref="x", yref="y", x=160, y=231, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=right_corner_3_2,
        xref="x", yref="y", x=90, y=300, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=mid_range_center_right,
        xref="x", yref="y", x=60, y=200, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=mid_range_right,
        xref="x", yref="y", x=100, y=80, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=right_corner_three,
        xref="x", yref="y", x=195, y=30, sizex=80, sizey=80,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.add_layout_image(   
    go.layout.Image(
        source=wnba_logo,
        xref="x", yref="y", x=-250, y=415, sizex=150, sizey=100,
        xanchor="left", yanchor="top",
        sizing="stretch", opacity=1, layer="above"))
fig.show()
